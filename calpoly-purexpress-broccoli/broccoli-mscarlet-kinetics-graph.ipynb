# %%
import matplotlib.pyplot as plt
import pandas as pd

data = {
    "Time (hours)": [
        0, 0.1667, 0.3333, 0.5, 0.6667, 0.8333, 1.0, 1.1667, 1.3333, 1.5,
        1.6667, 1.8333, 2.0, 2.1667, 2.3333, 2.5, 2.6667, 2.8333, 3.0,
        3.1667, 3.3333, 3.5, 3.6667, 3.8333, 4.0, 4.1667
    ],
    "Team 3 Broc (+)ctrl1": [
        27, 32.5, 47, 65.5, 83.5, 103.5, 121, 139, 156.5, 173,
        187.5, 204.5, 217, 231, 242.5, 250, 259, 265, 270.5, 273,
        276, 276, 276.5, 273.5, 272.5, 270
    ],
    "Team 3 Broc (+)ctrl2": [
        26.5, 32, 45.5, 63.5, 82, 101.5, 119, 136.5, 155.5, 169.5,
        186.5, 201.5, 214.5, 228.5, 239.5, 248, 257, 262.5, 268.5, 272,
        274.5, 275, 275, 274, 271, 268.5
    ],
    "Team 3 Broc (-)ctrl": [
        27, 25.5, 25, 24, 24, 25, 24.5, 25, 25.5, 24,
        24, 25.5, 24.5, 25.5, 25.5, 24, 25.5, 25.5, 25,
        25, 25.5, 25.5, 25, 25.5, 25.5, 25.5
    ],
    "Team 3 mScar (+)ctrl1": [
        16.5, 15.5, 16, 21.5, 36, 61, 96, 139, 188.5, 243,
        300.5, 358.5, 418, 473.5, 529.5, 580, 627, 662.5, 693,
        713, None, None, None, None, None, None
    ],
    "Team 3 mScar (+)ctrl2": [
        15.5, 14.5, 15.5, 20.5, 34, 59, 93.5, 137, 186.5, 240.5,
        298, 356.5, 416.5, 473, 527.5, 578, 622, 655.5, 688,
        707, None, None, None, None, None, None
    ],
    "Team 3 mScar (-)ctrl": [
        16.5, 14.5, 15, 15.5, 15, 15, 14.5, 13.5, 14.5, 14.5,
        15, 14.5, 15, 14.5, 15, 15, 15.5, 15.5, 15,
        15, None, None, None, None, None, None
    ],
}

df = pd.DataFrame(data)

fig, ax1 = plt.subplots(figsize=(7, 4.8), dpi=200)

markers = {
    "Team 3 Broc (+)ctrl1": "o",
    "Team 3 Broc (+)ctrl2": "^",
    "Team 3 Broc (-)ctrl": "s",
    "Team 3 mScar (+)ctrl1": "D",
    "Team 3 mScar (+)ctrl2": "P",
    "Team 3 mScar (-)ctrl": "X",
}

broc_cols = ["Team 3 Broc (+)ctrl1", "Team 3 Broc (+)ctrl2", "Team 3 Broc (-)ctrl"]
for col in broc_cols:
    ax1.scatter(df["Time (hours)"], df[col], s=22, marker=markers[col], label=col)

ax1.set_xlabel("Time (hours)", fontsize=12)
ax1.set_ylabel("Broccoli (RFU)", fontsize=12)
ax1.set_xlim(0, 5)
ax1.set_ylim(0, 300)
ax1.tick_params(axis="both", labelsize=10)
ax1.grid(False)

ax2 = ax1.twinx()

mscar_cols = ["Team 3 mScar (+)ctrl1", "Team 3 mScar (+)ctrl2", "Team 3 mScar (-)ctrl"]
for col in mscar_cols:
    ax2.scatter(df["Time (hours)"], df[col], s=22, marker=markers[col], label=col)

ax2.set_ylabel("mScarlet (RFU)", fontsize=12)
ax2.set_ylim(0, 800)
ax2.tick_params(axis="y", labelsize=10)
ax2.grid(False)

handles1, labels1 = ax1.get_legend_handles_labels()
handles2, labels2 = ax2.get_legend_handles_labels()
ax1.legend(
    handles1 + handles2,
    labels1 + labels2,
    loc="upper center",
    bbox_to_anchor=(0.5, -0.18),
    ncol=2,
    fontsize=8,
    frameon=False
)

plt.tight_layout()

png_path = "/mnt/data/Team3_Experiment1_Broccoli_mScarlet_Graph_no_title_no_grid.png"
pdf_path = "/mnt/data/Team3_Experiment1_Broccoli_mScarlet_Graph_no_title_no_grid.pdf"

plt.savefig(png_path, bbox_inches="tight")
plt.savefig(pdf_path, bbox_inches="tight")
plt.show()

print(f"Saved PNG: {png_path}")
print(f"Saved PDF: {pdf_path}")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 94
#      91 png_path = "/mnt/data/Team3_Experiment1_Broccoli_mScarlet_Graph_no_title_no_grid.png"
#      92 pdf_path = "/mnt/data/Team3_Experiment1_Broccoli_mScarlet_Graph_no_title_no_grid.pdf"
# ---> 94 plt.savefig(png_path, bbox_inches="tight")
#      95 plt.savefig(pdf_path, bbox_inches="tight")
#      96 plt.show()
#
# File /opt/conda/lib/python3.12/site-packages/matplotlib/pyplot.py:1250, in savefig(*args, **kwargs)
#    1247 fig = gcf()
#    1248 # savefig default implementation has no return, so mypy is unhappy
#    1249 # presumably this is here because subclasses can return?
# -> 1250 res = fig.savefig(*args, **kwargs)  # type: ignore[func-returns-value]
#    1251 fig.canvas.draw_idle()  # Need this if 'transparent=True', to reset colors.
#    1252 return res
#
# ...
